# %% [markdown]
# ### Extracting the URL

# %%
from Lenovo_Laptops_Function_File import *
url=get_url('lenovo laptops')
print(url)
# Out:
# ...
# https://www.flipkart.com/search?q=lenovo+laptops&sid=6bo%2Cb5g&as=on&as-show=on&otracker=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_ps&otracker1=AS_QueryStore_OrganicAutoSuggest_1_6_na_na_ps&as-pos=1&as-type=RECENT&suggestionId=lenovo+laptops%7CLaptops&requestId=b63e4ba2-73da-4bf5-bd2d-ec7b1b8f1f33&as-searchtext=lenovo

# %%
from Lenovo_Laptops_Function_File import *

main('lenovo_laptops')

# %% [markdown]
# ### Extracting Data in csv File

# %%
import pandas as pd
Data=pd.DataFrame(list)
Data.columns=['Name','Price','Link','Rating','Total Reviews','Description']
def make_clickable(val):
    return '<a target="_blank" href="{}">{}</a>'.format(val, val)
    
Data.style.format({'Link': make_clickable})
# Out:
# <style  type="text/css" >
# </style><table id="T_66d23d24_ae31_11eb_a10b_d8d0904811a7" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Name</th>        <th class="col_heading level0 col1" >Price</th>        <th class="col_heading level0 col2" >Link</th>        <th class="col_heading level0 col3" >Rating</th>        <th class="col_heading level0 col4" >Total Reviews</th>        <th class="col_heading level0 col5" >Description</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_66d23d24_ae31_11eb_a10b_d8d0904811a7level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_66d23d24_ae31_11eb_a10b_d8d0904811a7row0_col0" class="data row0 col0" >Lenovo Legion 5 Ryzen 5 Hexa Core 4600H - (8 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForc...</td>
#                         <td id="T_66d23d24_ae31_11eb_a10b_d8d0904811a7row0_col1" class="data row0 col1" >₹63,990</td>
# ...

# %%
len(list)
# Out:
# 139

# %%
Data.to_csv('d:Ishty Folder\Projects Python\Lenovo_Laptops_Flipkart_Data.csv', mode='a',header=True)
